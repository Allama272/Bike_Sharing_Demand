# %% [markdown]
# # Predict Bike Sharing Demand with AutoGluon Template

# %% [markdown]
# ## Project: Predict Bike Sharing Demand with AutoGluon
# This notebook is a template with each step that you need to complete for the project.
#
# Please fill in your code where there are explicit `?` markers in the notebook. You are welcome to add more cells and code as you see fit.
#
# Once you have completed all the code implementations, please export your notebook as a HTML file so the reviews can view your code. Make sure you have all outputs correctly outputted.
#
# `File-> Export Notebook As... -> Export Notebook as HTML`
#
# There is a writeup to complete as well after all code implememtation is done. Please answer all questions and attach the necessary tables and charts. You can complete the writeup in either markdown or PDF.
#
# Completing the code template and writeup template will cover all of the rubric points for this project.
#
# The rubric contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this notebook and also discuss the results in the writeup file.

# %%
pip install bokeh==2.0.1
# Out:
# Collecting bokeh==2.0.1
#   Downloading bokeh-2.0.1.tar.gz (8.6 MB)
#      ---------------------------------------- 8.6/8.6 MB 375.7 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: PyYAML>=3.10 in c:\users\lenovo\anaconda3\envs\myenv\lib\site-packages (from bokeh==2.0.1) (6.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\lenovo\anaconda3\envs\myenv\lib\site-packages (from bokeh==2.0.1) (2.8.2)
# Requirement already satisfied: Jinja2>=2.7 in c:\users\lenovo\anaconda3\envs\myenv\lib\site-packages (from bokeh==2.0.1) (3.0.3)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\lenovo\anaconda3\envs\myenv\lib\site-packages (from bokeh==2.0.1) (1.21.6)
# Requirement already satisfied: pillow>=4.0 in c:\users\lenovo\anaconda3\envs\myenv\lib\site-packages (from bokeh==2.0.1) (9.0.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\lenovo\anaconda3\envs\myenv\lib\site-packages (from bokeh==2.0.1) (21.3)
# Requirement already satisfied: tornado>=5 in c:\users\lenovo\anaconda3\envs\myenv\lib\site-packages (from bokeh==2.0.1) (6.1)
# Requirement already satisfied: typing_extensions>=3.7.4 in c:\users\lenovo\anaconda3\envs\myenv\lib\site-packages (from bokeh==2.0.1) (4.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\envs\myenv\lib\site-packages (from Jinja2>=2.7->bokeh==2.0.1) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\lenovo\anaconda3\envs\myenv\lib\site-packages (from packaging>=16.8->bokeh==2.0.1) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.1->bokeh==2.0.1) (1.16.0)
# Building wheels for collected packages: bokeh
#   Building wheel for bokeh (setup.py): started
#   Building wheel for bokeh (setup.py): finished with status 'done'
#   Created wheel for bokeh: filename=bokeh-2.0.1-py3-none-any.whl size=9080026 sha256=75f59654d64d2d777e64ed8b3259d8e10ec04f0a5cac2214f3f51a2ebd0ae208
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\00\1b\23\26649f4d0923cdfb0b6445e3d10d262a4824747b942a592dd1
# Successfully built bokeh
# Installing collected packages: bokeh
# Successfully installed bokeh-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import kaggle

# %%
# !kaggle competitions download -c bike-sharing-demand
# Out:
# Downloading bike-sharing-demand.zip to D:\Projects\Bike_Sharing_Demand-main\project
#   0%|          | 0.00/189k [00:00<?, ?B/s]
# 100%|##########| 189k/189k [00:00<00:00, 306kB/s]
# 100%|##########| 189k/189k [00:00<00:00, 306kB/s]
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd
from autogluon.tabular import TabularPredictor

# %%
import autogluon.core as ag

# %%
import numpy as np

# %%
# Create the train dataset in pandas by reading the csv
# Set the parsing of the datetime column so you can use some of the `dt` features in pandas later
train = pd.read_csv('data/train.csv')
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
# Simple output of the train dataset to view some of the min/max/varition of the dataset features.
train.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %%
# Create the test pandas dataframe in pandas by reading the csv, remember to parse the datetime!
test = pd.read_csv('data/test.csv')
test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
# Same thing as train and test dataset
submission = pd.read_csv('data/sampleSubmission.csv')
submission.head()
# Out:
#               datetime  count
# 0  2011-01-20 00:00:00      0
# 1  2011-01-20 01:00:00      0
# 2  2011-01-20 02:00:00      0
# 3  2011-01-20 03:00:00      0
# 4  2011-01-20 04:00:00      0

# %% [markdown]
# ## Step 3: Train a model using AutoGluon’s Tabular Prediction

# %% [markdown]
# Requirements:
# * We are prediting `count`, so it is the label we are setting.
# * Ignore `casual` and `registered` columns as they are also not present in the test dataset.
# * Use the `root_mean_squared_error` as the metric to use for evaluation.
# * Set a time limit of 10 minutes (600 seconds).
# * Use the preset `best_quality` to focus on creating the best model.

# %%
train.drop(['casual','registered'],axis=1,inplace=True)

# %%
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  count
# 0        81        0.0     16
# 1        80        0.0     40
# 2        80        0.0     32
# 3        75        0.0     13
# 4        75        0.0      1

# %%
predictor = TabularPredictor(label='count', eval_metric='root_mean_squared_error').fit(train, time_limit= 10*60, presets="best_quality")
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20220902_220133\"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 600s
# AutoGluon will save models to "AutogluonModels/ag-20220902_220133\"
# AutoGluon Version:  0.5.2
# Python Version:     3.9.12
# Operating System:   Windows
# Train Data Rows:    10886
# Train Data Columns: 9
# Label Column: count
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == int and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (977, 1, 191.57413, 181.14445)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6104.47 MB
# 	Train Data (Original)  Memory Usage: 1.52 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])                        : 5 | ['season', 'holiday', 'workingday', 'weather', 'humidity']
# 		('object', ['datetime_as_object']) : 1 | ['datetime']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])                  : 3 | ['season', 'weather', 'humidity']
# 		('int', ['bool'])            : 2 | ['holiday', 'workingday']
# 		('int', ['datetime_as_int']) : 5 | ['datetime', 'datetime.year', 'datetime.month', 'datetime.day', 'datetime.dayofweek']
# 	0.1s = Fit runtime
# 	9 features in original data used to generate 13 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.81 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.07s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 399.85s of the 599.92s of remaining time.
# 	-101.5882	 = Validation score   (-root_mean_squared_error)
# 	0.05s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 399.72s of the 599.8s of remaining time.
# 	-84.1464	 = Validation score   (-root_mean_squared_error)
# 	0.05s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 399.61s of the 599.69s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.4609	 = Validation score   (-root_mean_squared_error)
# 	8.79s	 = Training   runtime
# 	8.54s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 384.79s of the 584.86s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.0542	 = Validation score   (-root_mean_squared_error)
# 	3.79s	 = Training   runtime
# 	0.78s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 377.82s of the 577.89s of remaining time.
# 	-116.5438	 = Validation score   (-root_mean_squared_error)
# 	1.61s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 375.46s of the 575.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [56], in <cell line: 1>()
# ----> 1 predictor = TabularPredictor(label='count', eval_metric='root_mean_squared_error').fit(train, time_limit= 10*60, presets="best_quality")
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\utils\decorators.py:30, in unpack.<locals>._unpack_inner.<locals>._call(*args, **kwargs)
#      27 @functools.wraps(f)
#      28 def _call(*args, **kwargs):
#      29     gargs, gkwargs = g(*other_args, *args, **kwargs)
# ---> 30     return f(*gargs, **gkwargs)
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\tabular\predictor\predictor.py:831, in TabularPredictor.fit(self, train_data, tuning_data, time_limit, presets, hyperparameters, feature_metadata, infer_limit, infer_limit_batch_size, **kwargs)
#     823 core_kwargs = {
#     824     'ag_args': ag_args,
#     825     'ag_args_ensemble': ag_args_ensemble,
#    (...)
#     828     'feature_prune_kwargs': kwargs.get('feature_prune_kwargs', None)
#     829 }
#     830 self.save(silent=True)  # Save predictor to disk to enable prediction and training after interrupt
# --> 831 self._learner.fit(X=train_data, X_val=tuning_data, X_unlabeled=unlabeled_data,
#     832                   holdout_frac=holdout_frac, num_bag_folds=num_bag_folds, num_bag_sets=num_bag_sets,
#     833                   num_stack_levels=num_stack_levels,
#     834                   hyperparameters=hyperparameters, core_kwargs=core_kwargs,
#     835                   time_limit=time_limit, infer_limit=infer_limit, infer_limit_batch_size=infer_limit_batch_size,
#     836                   verbosity=verbosity, use_bag_holdout=use_bag_holdout)
#     837 self._set_post_fit_vars()
#     839 self._post_fit(
#     840     keep_only_best=kwargs['keep_only_best'],
#     841     refit_full=kwargs['refit_full'],
#    (...)
#     845     infer_limit=infer_limit,
#     846 )
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\tabular\learner\abstract_learner.py:118, in AbstractTabularLearner.fit(self, X, X_val, **kwargs)
#     116     raise AssertionError('Learner is already fit.')
#     117 self._validate_fit_input(X=X, X_val=X_val, **kwargs)
# --> 118 return self._fit(X=X, X_val=X_val, **kwargs)
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\tabular\learner\default_learner.py:126, in DefaultLearner._fit(self, X, X_val, X_unlabeled, holdout_frac, num_bag_folds, num_bag_sets, time_limit, infer_limit, infer_limit_batch_size, verbosity, **trainer_fit_kwargs)
#     123     self.eval_metric = trainer.eval_metric
#     125 self.save()
# --> 126 trainer.fit(
#     127     X=X,
#     128     y=y,
#     129     X_val=X_val,
#     130     y_val=y_val,
#     131     X_unlabeled=X_unlabeled,
#     132     holdout_frac=holdout_frac,
#     133     time_limit=time_limit_trainer,
#     134     infer_limit=infer_limit,
#     135     infer_limit_batch_size=infer_limit_batch_size,
#     136     groups=groups,
#     137     **trainer_fit_kwargs
#     138 )
#     139 self.save_trainer(trainer=trainer)
#     140 time_end = time.time()
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\tabular\trainer\auto_trainer.py:85, in AutoTrainer.fit(self, X, y, hyperparameters, X_val, y_val, X_unlabeled, holdout_frac, num_stack_levels, core_kwargs, time_limit, infer_limit, infer_limit_batch_size, use_bag_holdout, groups, **kwargs)
#      76     if not use_bag_holdout:
#      77         # TODO: User could be intending to blend instead. Add support for blend stacking.
#      78         #  This error message is necessary because when calculating out-of-fold predictions for user, we want to return them in the form given in train_data,
#      79         #  but if we merge train and val here, it becomes very confusing from a users perspective, especially because we reset index, making it impossible to match
#      80         #  the original train_data to the out-of-fold predictions from `predictor.get_oof_pred_proba()`.
#      81         raise AssertionError('X_val, y_val is not None, but bagged mode was specified. If calling from `TabularPredictor.fit()`, `tuning_data` must be None.\n'
#      82                              'Bagged mode does not use tuning data / validation data. Instead, all data (`train_data` and `tuning_data`) should be combined and specified as `train_data`.\n'
#      83                              'Bagging/Stacking with a held-out validation set (blend stacking) is not yet supported.')
# ---> 85 self._train_multi_and_ensemble(X=X,
#      86                                y=y,
#      87                                X_val=X_val,
#      88                                y_val=y_val,
#      89                                X_unlabeled=X_unlabeled,
#      90                                hyperparameters=hyperparameters,
#      91                                num_stack_levels=num_stack_levels,
#      92                                time_limit=time_limit,
#      93                                core_kwargs=core_kwargs,
#      94                                infer_limit=infer_limit,
#      95                                infer_limit_batch_size=infer_limit_batch_size,
#      96                                groups=groups)
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py:1665, in AbstractTrainer._train_multi_and_ensemble(self, X, y, X_val, y_val, hyperparameters, X_unlabeled, num_stack_levels, time_limit, groups, **kwargs)
#    1663     self._num_rows_train += len(X_val)
#    1664 self._num_cols_train = len(list(X.columns))
# -> 1665 model_names_fit = self.train_multi_levels(X, y, hyperparameters=hyperparameters, X_val=X_val, y_val=y_val,
#    1666                                           X_unlabeled=X_unlabeled, level_start=1, level_end=num_stack_levels+1, time_limit=time_limit, **kwargs)
#    1667 if len(self.get_model_names()) == 0:
#    1668     raise ValueError('AutoGluon did not successfully train any models')
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py:295, in AbstractTrainer.train_multi_levels(self, X, y, hyperparameters, X_val, y_val, X_unlabeled, base_model_names, core_kwargs, aux_kwargs, level_start, level_end, time_limit, name_suffix, relative_stack, level_time_modifier, infer_limit, infer_limit_batch_size)
#     293         core_kwargs_level['time_limit'] = core_kwargs_level.get('time_limit', time_limit_core)
#     294         aux_kwargs_level['time_limit'] = aux_kwargs_level.get('time_limit', time_limit_aux)
# --> 295     base_model_names, aux_models = self.stack_new_level(
#     296         X=X, y=y, X_val=X_val, y_val=y_val, X_unlabeled=X_unlabeled,
#     297         models=hyperparameters, level=level, base_model_names=base_model_names,
#     298         core_kwargs=core_kwargs_level, aux_kwargs=aux_kwargs_level, name_suffix=name_suffix,
#     299         infer_limit=infer_limit, infer_limit_batch_size=infer_limit_batch_size,
#     300     )
#     301     model_names_fit += base_model_names + aux_models
#     302 self._time_limit = None
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py:405, in AbstractTrainer.stack_new_level(self, X, y, models, X_val, y_val, X_unlabeled, level, base_model_names, core_kwargs, aux_kwargs, name_suffix, infer_limit, infer_limit_batch_size)
#     403     core_kwargs['name_suffix'] = core_kwargs.get('name_suffix', '') + name_suffix
#     404     aux_kwargs['name_suffix'] = aux_kwargs.get('name_suffix', '') + name_suffix
# --> 405 core_models = self.stack_new_level_core(X=X, y=y, X_val=X_val, y_val=y_val, X_unlabeled=X_unlabeled, models=models,
#     406                                         level=level, infer_limit=infer_limit, infer_limit_batch_size=infer_limit_batch_size, base_model_names=base_model_names, **core_kwargs)
#     408 if X_val is None:
#     409     aux_models = self.stack_new_level_aux(X=X, y=y, base_model_names=core_models, level=level+1,
#     410                                           infer_limit=infer_limit, infer_limit_batch_size=infer_limit_batch_size, **aux_kwargs)
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py:496, in AbstractTrainer.stack_new_level_core(self, X, y, models, X_val, y_val, X_unlabeled, level, base_model_names, stack_name, ag_args, ag_args_fit, ag_args_ensemble, excluded_model_types, ensemble_type, name_suffix, get_models_func, refit_full, infer_limit, infer_limit_batch_size, **kwargs)
#     493 fit_kwargs = dict(num_classes=self.num_classes)
#     495 # FIXME: TODO: v0.1 X_unlabeled isn't cached so it won't be available during refit_full or fit_extra.
# --> 496 return self._train_multi(X=X_init, y=y, X_val=X_val, y_val=y_val, X_unlabeled=X_unlabeled,
#     497                          models=models, level=level, stack_name=stack_name, compute_score=compute_score, fit_kwargs=fit_kwargs, **kwargs)
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py:1635, in AbstractTrainer._train_multi(self, X, y, models, hyperparameter_tune_kwargs, feature_prune_kwargs, k_fold, n_repeats, n_repeat_start, time_limit, **kwargs)
#    1633 if n_repeat_start == 0:
#    1634     time_start = time.time()
# -> 1635     model_names_trained = self._train_multi_initial(X=X, y=y, models=models, k_fold=k_fold, n_repeats=n_repeats_initial, hyperparameter_tune_kwargs=hyperparameter_tune_kwargs,
#    1636                                                     feature_prune_kwargs=feature_prune_kwargs, time_limit=time_limit, **kwargs)
#    1637     n_repeat_start = n_repeats_initial
#    1638     if time_limit is not None:
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py:1532, in AbstractTrainer._train_multi_initial(self, X, y, models, k_fold, n_repeats, hyperparameter_tune_kwargs, time_limit, feature_prune_kwargs, **kwargs)
#    1530         k_fold_start = 1
#    1531     bagged_time_limit = time_limit - (time.time() - bagged_time_start) if time_limit is not None else None
# -> 1532     models = self._train_multi_fold(models=models, hyperparameter_tune_kwargs=None, k_fold_start=k_fold_start,
#    1533                                     k_fold_end=k_fold, n_repeats=n_repeats, n_repeat_start=0, time_limit=bagged_time_limit, **fit_args)
#    1535 multi_fold_time_elapsed = time.time() - multi_fold_time_start
#    1536 if time_limit is not None:
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py:1606, in AbstractTrainer._train_multi_fold(self, X, y, models, time_limit, time_split, time_ratio, hyperparameter_tune_kwargs, **kwargs)
#    1604         time_start_model = time.time()
#    1605         time_left = time_limit - (time_start_model - time_start)
# -> 1606 model_name_trained_lst = self._train_single_full(X, y, model, time_limit=time_left, hyperparameter_tune_kwargs=hyperparameter_tune_kwargs_model, **kwargs)
#    1608 if self.low_memory:
#    1609     del model
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py:1419, in AbstractTrainer._train_single_full(self, X, y, model, X_unlabeled, X_val, y_val, X_pseudo, y_pseudo, feature_prune, hyperparameter_tune_kwargs, stack_name, k_fold, k_fold_start, k_fold_end, n_repeats, n_repeat_start, level, time_limit, fit_kwargs, compute_score, **kwargs)
#    1417         bagged_model_fit_kwargs = self._get_bagged_model_fit_kwargs(k_fold=k_fold, k_fold_start=k_fold_start, k_fold_end=k_fold_end, n_repeats=n_repeats, n_repeat_start=n_repeat_start)
#    1418         model_fit_kwargs.update(bagged_model_fit_kwargs)
# -> 1419     model_names_trained = self._train_and_save(
#    1420         X=X,
#    1421         y=y,
#    1422         model=model,
#    1423         X_val=X_val,
#    1424         y_val=y_val,
#    1425         X_unlabeled=X_unlabeled,
#    1426         stack_name=stack_name,
#    1427         level=level,
#    1428         compute_score=compute_score,
#    1429         **model_fit_kwargs
#    1430     )
#    1431 self.save()
#    1432 return model_names_trained
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py:1126, in AbstractTrainer._train_and_save(self, X, y, model, X_val, y_val, stack_name, level, compute_score, **model_fit_kwargs)
#    1124     model = self._train_single(X_w_pseudo, y_w_pseudo, model, X_val, y_val, **model_fit_kwargs)
#    1125 else:
# -> 1126     model = self._train_single(X, y, model, X_val, y_val, **model_fit_kwargs)
#    1128 fit_end_time = time.time()
#    1129 if self.weight_evaluation:
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\trainer\abstract_trainer.py:1083, in AbstractTrainer._train_single(self, X, y, model, X_val, y_val, **model_fit_kwargs)
#    1078 def _train_single(self, X, y, model: AbstractModel, X_val=None, y_val=None, **model_fit_kwargs) -> AbstractModel:
#    1079     """
#    1080     Trains model but does not add the trained model to this Trainer.
#    1081     Returns trained model object.
#    1082     """
# -> 1083     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, **model_fit_kwargs)
#    1084     return model
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\models\abstract\abstract_model.py:587, in AbstractModel.fit(self, **kwargs)
#     585 self.validate_fit_resources(**kwargs)
#     586 self._validate_fit_memory_usage(**kwargs)
# --> 587 out = self._fit(**kwargs)
#     588 if out is None:
#     589     out = self
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\models\ensemble\stacker_ensemble_model.py:154, in StackerEnsembleModel._fit(self, X, y, compute_base_preds, time_limit, **kwargs)
#     152 if time_limit is not None:
#     153     time_limit = time_limit - (time.time() - start_time)
# --> 154 return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py:232, in BaggedEnsembleModel._fit(self, X, y, X_val, y_val, X_pseudo, y_pseudo, k_fold, k_fold_start, k_fold_end, n_repeats, n_repeat_start, groups, **kwargs)
#     230         # Reserve time for final refit model
#     231         kwargs['time_limit'] = kwargs['time_limit'] * folds_to_fit / (folds_to_fit + 1.2)
# --> 232 self._fit_folds(X=X, y=y, model_base=model_base, X_pseudo=X_pseudo, y_pseudo=y_pseudo,
#     233                 k_fold=k_fold, k_fold_start=k_fold_start, k_fold_end=k_fold_end,
#     234                 n_repeats=n_repeats, n_repeat_start=n_repeat_start, save_folds=save_bag_folds, groups=groups, **kwargs)
#     235 # FIXME: Don't save folds except for refit
#     236 # FIXME: Cleanup self
#     237 # FIXME: Don't add `_FULL` to name
#     238 # FIXME: Support `can_refit_full=False` models
#     239 if refit_folds:
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\models\ensemble\bagged_ensemble_model.py:503, in BaggedEnsembleModel._fit_folds(self, X, y, model_base, X_pseudo, y_pseudo, k_fold, k_fold_start, k_fold_end, n_repeats, n_repeat_start, time_limit, sample_weight, save_folds, groups, **kwargs)
#     501 for fold_fit_args in fold_fit_args_list:
#     502     fold_fitting_strategy.schedule_fold_model_fit(**fold_fit_args)
# --> 503 fold_fitting_strategy.after_all_folds_scheduled()
#     505 for model in models:
#     506     # No need to add child times or save child here as this already occurred in the fold_fitting_strategy
#     507     self.add_child(model=model, add_child_times=False)
#
# File ~\anaconda3\envs\myenv\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py:421, in ParallelLocalFoldFittingStrategy.after_all_folds_scheduled(self)
#     419 unfinished = job_refs
#     420 while unfinished:
# --> 421     finished, unfinished = self.ray.wait(unfinished, num_returns=1)
#     422     finished = finished[0]
#     423     try:
#
# File ~\anaconda3\envs\myenv\lib\site-packages\ray\_private\client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     103     if func.__name__ != "init" or is_client_mode_enabled_by_default:
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\myenv\lib\site-packages\ray\worker.py:2015, in wait(object_refs, num_returns, timeout, fetch_local)
#    2013 timeout = timeout if timeout is not None else 10 ** 6
#    2014 timeout_milliseconds = int(timeout * 1000)
# -> 2015 ready_ids, remaining_ids = worker.core_worker.wait(
#    2016     object_refs,
#    2017     num_returns,
#    2018     timeout_milliseconds,
#    2019     worker.current_task_id,
#    2020     fetch_local,
#    2021 )
#    2022 return ready_ids, remaining_ids
#
# File python\ray\_raylet.pyx:1403, in ray._raylet.CoreWorker.wait()
#
# File python\ray\_raylet.pyx:169, in ray._raylet.check_status()
#
# KeyboardInterrupt:

# %% [markdown]
# ### Review AutoGluon's training run with ranking of models that did the best.

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model   score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3  -50.257112      12.929147  366.492439                0.000000           0.235512            3       True         22
# 1   NeuralNetFastAI_BAG_L2  -51.272288      11.861319  267.756280                0.296489          22.385300            2       True         18
# 2   RandomForestMSE_BAG_L2  -53.430250      11.982179  251.280609                0.417350           5.909628            2       True         15
# 3     ExtraTreesMSE_BAG_L2  -54.023319      11.976223  247.310938                0.411393           1.939958            2       True         17
# 4     LightGBMLarge_BAG_L2  -54.852476      11.781393  252.154891                0.216563           6.783910            2       True         21
# 5          LightGBM_BAG_L2  -54.910914      11.737442  248.942029                0.172612           3.571048            2       True         14
# 6    NeuralNetTorch_BAG_L2  -54.943643      11.803915  336.022040                0.239085          90.651060            2       True         20
# 7           XGBoost_BAG_L2  -54.987724      11.654600  252.555773                0.089771           7.184793            2       True         19
# 8          CatBoost_BAG_L2  -55.708411      11.587229  271.819902                0.022400          26.448922            2       True         16
# 9        LightGBMXT_BAG_L2  -60.025657      14.294386  256.022885                2.729556          10.651904            2       True         13
# 10   KNeighborsDist_BAG_L1  -84.146423       0.017005    0.052011                0.017005           0.052011            1       True          2
# 11     WeightedEnsemble_L2  -84.146423       0.018025    0.367152                0.001020           0.315141            2       True         12
# 12   KNeighborsUnif_BAG_L1 -101.588176       0.016004    0.052012                0.016004           0.052012            1       True          1
# 13  RandomForestMSE_BAG_L1 -116.543822       0.361586    1.496843                0.361586           1.496843            1       True          5
# 14    ExtraTreesMSE_BAG_L1 -124.594043       0.346280    1.054101                0.346280           1.054101            1       True          7
# 15    LightGBMLarge_BAG_L1 -130.132290       0.539920    4.787623                0.539920           4.787623            1       True         11
# 16         CatBoost_BAG_L1 -130.461205       0.025006  117.457501                0.025006         117.457501            1       True          6
# 17         LightGBM_BAG_L1 -131.054162       0.741669    3.389189                0.741669           3.389189            1       True          4
# 18       LightGBMXT_BAG_L1 -131.460909       8.951774    8.336376                8.951774           8.336376            1       True          3
# 19          XGBoost_BAG_L1 -131.624665       0.167831    5.197966                0.167831           5.197966            1       True          9
# 20  NeuralNetFastAI_BAG_L1 -135.845258       0.205381   19.628907                0.205381          19.628907            1       True          8
# 21   NeuralNetTorch_BAG_L1 -138.119903       0.192373   83.918450                0.192373          83.918450            1       True         10
# Number of models trained: 22
# Types of models trained:
# {'StackerEnsembleModel_KNN', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'WeightedEnsembleModel', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_LGB'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# ('int', [])                  : 3 | ['season', 'weather', 'humidity']
# ('int', ['bool'])            : 2 | ['holiday', 'workingday']
# ('int', ['datetime_as_int']) : 5 | ['datetime', 'datetime.year', 'datetime.month', 'datetime.day', 'datetime.dayofweek']
# *** End of fit() summary ***
# C:\Users\Lenovo\anaconda3\envs\myenv\lib\site-packages\autogluon\core\utils\plots.py:138: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': -101.58817625927213,
#   'KNeighborsDist_BAG_L1': -84.14642264302962,
#   'LightGBMXT_BAG_L1': -131.46090891834504,
#   'LightGBM_BAG_L1': -131.054161598899,
#   'RandomForestMSE_BAG_L1': -116.54382177152374,
#   'CatBoost_BAG_L1': -130.46120460893414,
#   'ExtraTreesMSE_BAG_L1': -124.59404339731908,
#   'NeuralNetFastAI_BAG_L1': -135.84525833569566,
#   'XGBoost_BAG_L1': -131.62466543942023,
#   'NeuralNetTorch_BAG_L1': -138.11990257568806,
#   'LightGBMLarge_BAG_L1': -130.13228993716103,
#   'WeightedEnsemble_L2': -84.14642264302962,
#   'LightGBMXT_BAG_L2': -60.02565671182744,
#   'LightGBM_BAG_L2': -54.910913587236266,
#   'RandomForestMSE_BAG_L2': -53.43024978662885,
#   'CatBoost_BAG_L2': -55.70841135070985,
#   'ExtraTreesMSE_BAG_L2': -54.02331853159644,
#   'NeuralNetFastAI_BAG_L2': -51.27228754995282,
#   'XGBoost_BAG_L2': -54.98772405789228,
#   'NeuralNetTorch_BAG_L2': -54.943642783242005,
#   'LightGBMLarge_BAG_L2': -54.85247607491618,
#   'WeightedEnsemble_L3': -50.257112296590925},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': 'AutogluonModels/ag-20220901_220438\\models\\KNeighborsUnif_BAG_L1\\',
#   'KNeighborsDist_BAG_L1': 'AutogluonModels/ag-20220901_220438\\models\\KNeighborsDist_BAG_L1\\',
#   'LightGBMXT_BAG_L1': 'AutogluonModels/ag-20220901_220438\\models\\LightGBMXT_BAG_L1\\',
#   'LightGBM_BAG_L1': 'AutogluonModels/ag-20220901_220438\\models\\LightGBM_BAG_L1\\',
#   'RandomForestMSE_BAG_L1': 'AutogluonModels/ag-20220901_220438\\models\\RandomForestMSE_BAG_L1\\',
#   'CatBoost_BAG_L1': 'AutogluonModels/ag-20220901_220438\\models\\CatBoost_BAG_L1\\',
#   'ExtraTreesMSE_BAG_L1': 'AutogluonModels/ag-20220901_220438\\models\\ExtraTreesMSE_BAG_L1\\',
#   'NeuralNetFastAI_BAG_L1': 'AutogluonModels/ag-20220901_220438\\models\\NeuralNetFastAI_BAG_L1\\',
#   'XGBoost_BAG_L1': 'AutogluonModels/ag-20220901_220438\\models\\XGBoost_BAG_L1\\',
#   'NeuralNetTorch_BAG_L1': 'AutogluonModels/ag-20220901_220438\\models\\NeuralNetTorch_BAG_L1\\',
#   'LightGBMLarge_BAG_L1': 'AutogluonModels/ag-20220901_220438\\models\\LightGBMLarge_BAG_L1\\',
#   'WeightedEnsemble_L2': 'AutogluonModels/ag-20220901_220438\\models\\WeightedEnsemble_L2\\',
#   'LightGBMXT_BAG_L2': 'AutogluonModels/ag-20220901_220438\\models\\LightGBMXT_BAG_L2\\',
#   'LightGBM_BAG_L2': 'AutogluonModels/ag-20220901_220438\\models\\LightGBM_BAG_L2\\',
#   'RandomForestMSE_BAG_L2': 'AutogluonModels/ag-20220901_220438\\models\\RandomForestMSE_BAG_L2\\',
#   'CatBoost_BAG_L2': 'AutogluonModels/ag-20220901_220438\\models\\CatBoost_BAG_L2\\',
#   'ExtraTreesMSE_BAG_L2': 'AutogluonModels/ag-20220901_220438\\models\\ExtraTreesMSE_BAG_L2\\',
#   'NeuralNetFastAI_BAG_L2': 'AutogluonModels/ag-20220901_220438\\models\\NeuralNetFastAI_BAG_L2\\',
#   'XGBoost_BAG_L2': 'AutogluonModels/ag-20220901_220438\\models\\XGBoost_BAG_L2\\',
#   'NeuralNetTorch_BAG_L2': 'AutogluonModels/ag-20220901_220438\\models\\NeuralNetTorch_BAG_L2\\',
#   'LightGBMLarge_BAG_L2': 'AutogluonModels/ag-20220901_220438\\models\\LightGBMLarge_BAG_L2\\',
#   'WeightedEnsemble_L3': 'AutogluonModels/ag-20220901_220438\\models\\WeightedEnsemble_L3\\'},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.052011728286743164,
#   'KNeighborsDist_BAG_L1': 0.05201101303100586,
#   'LightGBMXT_BAG_L1': 8.336376428604126,
#   'LightGBM_BAG_L1': 3.3891892433166504,
#   'RandomForestMSE_BAG_L1': 1.496842622756958,
#   'CatBoost_BAG_L1': 117.45750141143799,
#   'ExtraTreesMSE_BAG_L1': 1.0541014671325684,
#   'NeuralNetFastAI_BAG_L1': 19.628907442092896,
#   'XGBoost_BAG_L1': 5.1979663372039795,
#   'NeuralNetTorch_BAG_L1': 83.91844964027405,
#   'LightGBMLarge_BAG_L1': 4.787622928619385,
#   'WeightedEnsemble_L2': 0.315140962600708,
#   'LightGBMXT_BAG_L2': 10.651904344558716,
#   'LightGBM_BAG_L2': 3.5710484981536865,
#   'RandomForestMSE_BAG_L2': 5.909628391265869,
#   'CatBoost_BAG_L2': 26.44892168045044,
#   'ExtraTreesMSE_BAG_L2': 1.939958095550537,
#   'NeuralNetFastAI_BAG_L2': 22.385299921035767,
#   'XGBoost_BAG_L2': 7.184792995452881,
#   'NeuralNetTorch_BAG_L2': 90.65106010437012,
#   'LightGBMLarge_BAG_L2': 6.783910274505615,
#   'WeightedEnsemble_L3': 0.23551249504089355},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.01600360870361328,
#   'KNeighborsDist_BAG_L1': 0.017004966735839844,
#   'LightGBMXT_BAG_L1': 8.95177435874939,
#   'LightGBM_BAG_L1': 0.7416694164276123,
#   'RandomForestMSE_BAG_L1': 0.3615860939025879,
#   'CatBoost_BAG_L1': 0.025005817413330078,
#   'ExtraTreesMSE_BAG_L1': 0.3462796211242676,
#   'NeuralNetFastAI_BAG_L1': 0.20538115501403809,
#   'XGBoost_BAG_L1': 0.1678311824798584,
#   'NeuralNetTorch_BAG_L1': 0.19237327575683594,
#   'LightGBMLarge_BAG_L1': 0.5399203300476074,
#   'WeightedEnsemble_L2': 0.001020193099975586,
#   'LightGBMXT_BAG_L2': 2.729556083679199,
#   'LightGBM_BAG_L2': 0.17261219024658203,
#   'RandomForestMSE_BAG_L2': 0.41734957695007324,
#   'CatBoost_BAG_L2': 0.0223996639251709,
#   'ExtraTreesMSE_BAG_L2': 0.4113931655883789,
#   'NeuralNetFastAI_BAG_L2': 0.29648923873901367,
#   'XGBoost_BAG_L2': 0.08977055549621582,
#   'NeuralNetTorch_BAG_L2': 0.23908519744873047,
#   'LightGBMLarge_BAG_L2': 0.21656346321105957,
#   'WeightedEnsemble_L3': 0.0},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                      model   score_val  pred_time_val    fit_time  \
#  0      WeightedEnsemble_L3  -50.257112      12.929147  366.492439
#  1   NeuralNetFastAI_BAG_L2  -51.272288      11.861319  267.756280
#  2   RandomForestMSE_BAG_L2  -53.430250      11.982179  251.280609
#  3     ExtraTreesMSE_BAG_L2  -54.023319      11.976223  247.310938
#  4     LightGBMLarge_BAG_L2  -54.852476      11.781393  252.154891
#  5          LightGBM_BAG_L2  -54.910914      11.737442  248.942029
#  6    NeuralNetTorch_BAG_L2  -54.943643      11.803915  336.022040
#  7           XGBoost_BAG_L2  -54.987724      11.654600  252.555773
#  8          CatBoost_BAG_L2  -55.708411      11.587229  271.819902
#  9        LightGBMXT_BAG_L2  -60.025657      14.294386  256.022885
#  10   KNeighborsDist_BAG_L1  -84.146423       0.017005    0.052011
#  11     WeightedEnsemble_L2  -84.146423       0.018025    0.367152
#  12   KNeighborsUnif_BAG_L1 -101.588176       0.016004    0.052012
#  13  RandomForestMSE_BAG_L1 -116.543822       0.361586    1.496843
#  14    ExtraTreesMSE_BAG_L1 -124.594043       0.346280    1.054101
#  15    LightGBMLarge_BAG_L1 -130.132290       0.539920    4.787623
#  16         CatBoost_BAG_L1 -130.461205       0.025006  117.457501
#  17         LightGBM_BAG_L1 -131.054162       0.741669    3.389189
#  18       LightGBMXT_BAG_L1 -131.460909       8.951774    8.336376
#  19          XGBoost_BAG_L1 -131.624665       0.167831    5.197966
#  20  NeuralNetFastAI_BAG_L1 -135.845258       0.205381   19.628907
#  21   NeuralNetTorch_BAG_L1 -138.119903       0.192373   83.918450
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.000000           0.235512            3       True
#  1                 0.296489          22.385300            2       True
#  2                 0.417350           5.909628            2       True
#  3                 0.411393           1.939958            2       True
#  4                 0.216563           6.783910            2       True
#  5                 0.172612           3.571048            2       True
#  6                 0.239085          90.651060            2       True
#  7                 0.089771           7.184793            2       True
#  8                 0.022400          26.448922            2       True
#  9                 2.729556          10.651904            2       True
#  10                0.017005           0.052011            1       True
#  11                0.001020           0.315141            2       True
#  12                0.016004           0.052012            1       True
#  13                0.361586           1.496843            1       True
#  14                0.346280           1.054101            1       True
#  15                0.539920           4.787623            1       True
#  16                0.025006         117.457501            1       True
#  17                0.741669           3.389189            1       True
#  18                8.951774           8.336376            1       True
#  19                0.167831           5.197966            1       True
#  20                0.205381          19.628907            1       True
#  21                0.192373          83.918450            1       True
#
#      fit_order
#  0          22
#  1          18
#  2          15
#  3          17
#  4          21
#  5          14
#  6          20
#  7          19
#  8          16
#  9          13
#  10          2
#  11         12
#  12          1
#  13          5
#  14          7
#  15         11
#  16          6
#  17          4
#  18          3
#  19          9
#  20          8
#  21         10  }

# %% [markdown]
# ### Create predictions from test dataset

# %%
predictions =predictor.predict(test)

predictions.head()
# Out:
# C:\Users\Lenovo\anaconda3\envs\myenv\lib\site-packages\xgboost\compat.py:31: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# 0    24.216393
# 1    40.614311
# 2    46.007603
# 3    47.458683
# 4    49.840912
# Name: count, dtype: float32

# %% [markdown]
# #### NOTE: Kaggle will reject the submission if we don't set everything to be > 0.

# %%
# Describe the `predictions` series to see if there are any negative values
predictions.describe()
# Out:
# count    6493.000000
# mean       99.750961
# std        88.438271
# min        -0.903439
# 25%        21.550217
# 50%        66.916191
# 75%       168.007385
# max       349.708832
# Name: count, dtype: float64

# %%
# How many negative values do we have?
b=np.array(predictions)
print(sum(b<0))
# Out:
# 2

# %%
# Set them to zero
predictions=np.where(predictions < 0.0, 0, predictions)

# %%
b=np.array(predictions)
print(sum(b<0))
# Out:
# 0

# %%
predictions= pd.DataFrame(predictions)

# %%
predictions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       6493 non-null   float32
# dtypes: float32(1)
# memory usage: 25.5 KB

# %%
predictions.describe()
# Out:
#                  0
# count  6493.000000
# mean     99.751228
# std      88.437981
# min       0.000000
# 25%      21.550217
# 50%      66.916191
# 75%     168.007385
# max     349.708832

# %% [markdown]
# ### Set predictions to submission dataframe, save, and submit

# %%
submission["count"] = predictions
submission.to_csv("submission.csv", index=False)

# %%
# !kaggle competitions submit -c bike-sharing-demand -f submission.csv -m "first raw submission"
# Out:
# Successfully submitted to Bike Sharing Demand
#   0%|          | 0.00/195k [00:00<?, ?B/s]
#   4%|4         | 8.00k/195k [00:00<00:08, 21.6kB/s]
#  41%|####1     | 80.0k/195k [00:00<00:00, 213kB/s]
#  66%|######5   | 128k/195k [00:00<00:00, 233kB/s]
#  99%|#########8| 192k/195k [00:00<00:00, 315kB/s]
# 100%|##########| 195k/195k [00:03<00:00, 55.2kB/s]

# %% [markdown]
# #### View submission via the command line or in the web browser under the competition's page - `My Submissions`

# %%
# !kaggle competitions submissions -c bike-sharing-demand | tail -n +1 | head -n 6
# Out:
# 'tail' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# #### Initial score of `1.806441.80644`

# %% [markdown]
# ## Step 4: Exploratory Data Analysis and Creating an additional feature
# * Any additional feature will do, but a great suggestion would be to separate out the datetime into hour, day, or month parts.

# %%
# Create a histogram of all features to show the distribution of each one relative to the data. This is part of the exploritory data analysis
train.hist();

# %%
train['datetime']=pd.to_datetime(train['datetime'])

# %%
test['datetime']=pd.to_datetime(test['datetime'])

# %%
train.datetime.dtype
# Out:
# dtype('<M8[ns]')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  datetime64[ns]
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   count       10886 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(6)
# memory usage: 850.6 KB

# %%
# create a new feature
train['weekday'] = train['datetime'].dt.dayofweek
test['weekday'] = test['datetime'].dt.dayofweek

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  count  weekday
# 0        81        0.0     16        5
# 1        80        0.0     40        5
# 2        80        0.0     32        5
# 3        75        0.0     13        5
# 4        75        0.0      1        5

# %% [markdown]
# ## Make category types for these so models know they are not just numbers
# * AutoGluon originally sees these as ints, but in reality they are int representations of a category.
# * Setting the dtype to category will classify these as categories in AutoGluon.

# %%
train["season"] = train.season.astype('category')
train["weather"] = train.weather.astype('category')
train['weekday'] = train.weekday.astype('category')
test['weekday'] = test.weekday.astype('category')
test["season"] = test.season.astype('category')
test["weather"] = test.weather.astype('category')

# %%
# View are new feature
train.head()
# Out:
#              datetime season  holiday  workingday weather  temp   atemp  \
# 0 2011-01-01 00:00:00      1        0           0       1  9.84  14.395
# 1 2011-01-01 01:00:00      1        0           0       1  9.02  13.635
# 2 2011-01-01 02:00:00      1        0           0       1  9.02  13.635
# 3 2011-01-01 03:00:00      1        0           0       1  9.84  14.395
# 4 2011-01-01 04:00:00      1        0           0       1  9.84  14.395
#
#    humidity  windspeed  count weekday
# 0        81        0.0     16       5
# 1        80        0.0     40       5
# 2        80        0.0     32       5
# 3        75        0.0     13       5
# 4        75        0.0      1       5

# %%
# View histogram of all features again now with the new feature
train.hist()
# Out:
# array([[<AxesSubplot:title={'center':'datetime'}>,
#         <AxesSubplot:title={'center':'holiday'}>,
#         <AxesSubplot:title={'center':'workingday'}>],
#        [<AxesSubplot:title={'center':'temp'}>,
#         <AxesSubplot:title={'center':'atemp'}>,
#         <AxesSubplot:title={'center':'humidity'}>],
#        [<AxesSubplot:title={'center':'windspeed'}>,
#         <AxesSubplot:title={'center':'count'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ## Step 5: Rerun the model with the same settings as before, just with more features

# %%
predictor_new_features = TabularPredictor(label='count', eval_metric='root_mean_squared_error').fit(train, time_limit= 10*60, presets="best_quality")
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20220902_205304\"
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 600s
# AutoGluon will save models to "AutogluonModels/ag-20220902_205304\"
# AutoGluon Version:  0.5.2
# Python Version:     3.9.12
# Operating System:   Windows
# Train Data Rows:    10886
# Train Data Columns: 10
# Label Column: count
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == int and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (977, 1, 191.57413, 181.14445)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    7494.95 MB
# 	Train Data (Original)  Memory Usage: 0.64 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('category', []) : 3 | ['season', 'weather', 'weekday']
# 		('datetime', []) : 1 | ['datetime']
# 		('float', [])    : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])      : 3 | ['holiday', 'workingday', 'humidity']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])             : 3 | ['season', 'weather', 'weekday']
# 		('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])                  : 1 | ['humidity']
# 		('int', ['bool'])            : 2 | ['holiday', 'workingday']
# 		('int', ['datetime_as_int']) : 5 | ['datetime', 'datetime.year', 'datetime.month', 'datetime.day', 'datetime.dayofweek']
# 	0.1s = Fit runtime
# 	10 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.67 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.09s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 399.84s of the 599.91s of remaining time.
# 	-101.5882	 = Validation score   (-root_mean_squared_error)
# 	0.04s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 399.74s of the 599.81s of remaining time.
# 	-84.1464	 = Validation score   (-root_mean_squared_error)
# 	0.04s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 399.67s of the 599.74s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.1592	 = Validation score   (-root_mean_squared_error)
# 	9.56s	 = Training   runtime
# 	9.18s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 378.68s of the 578.75s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-130.3394	 = Validation score   (-root_mean_squared_error)
# 	4.58s	 = Training   runtime
# 	0.94s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 370.66s of the 570.73s of remaining time.
# 	-116.705	 = Validation score   (-root_mean_squared_error)
# 	1.85s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 368.12s of the 568.19s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.9263	 = Validation score   (-root_mean_squared_error)
# 	296.03s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 68.91s of the 268.98s of remaining time.
# 	-124.3955	 = Validation score   (-root_mean_squared_error)
# 	0.88s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 67.34s of the 267.41s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.3198	 = Validation score   (-root_mean_squared_error)
# 	23.33s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 40.05s of the 240.12s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.1277	 = Validation score   (-root_mean_squared_error)
# 	4.55s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 31.33s of the 231.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-140.7357	 = Validation score   (-root_mean_squared_error)
# 	28.31s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 199.83s of remaining time.
# 	-84.1464	 = Validation score   (-root_mean_squared_error)
# 	0.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 9 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 199.56s of the 199.55s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-61.518	 = Validation score   (-root_mean_squared_error)
# 	10.33s	 = Training   runtime
# 	4.43s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 184.54s of the 184.53s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-54.667	 = Validation score   (-root_mean_squared_error)
# 	3.8s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 177.47s of the 177.47s of remaining time.
# 	-53.0287	 = Validation score   (-root_mean_squared_error)
# 	5.39s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 171.41s of the 171.4s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-55.4565	 = Validation score   (-root_mean_squared_error)
# 	112.42s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 56.03s of the 56.02s of remaining time.
# 	-54.025	 = Validation score   (-root_mean_squared_error)
# 	1.58s	 = Training   runtime
# 	0.4s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 53.78s of the 53.77s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-52.3926	 = Validation score   (-root_mean_squared_error)
# 	20.69s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 30.14s of the 30.13s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-54.9216	 = Validation score   (-root_mean_squared_error)
# 	6.4s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 20.48s of the 20.48s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-63.4817	 = Validation score   (-root_mean_squared_error)
# 	19.64s	 = Training   runtime
# 	0.3s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -2.91s of remaining time.
# 	-50.7169	 = Validation score   (-root_mean_squared_error)
# 	0.22s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 603.45s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20220902_205304\")

# %%
predictor_new_features.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model   score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3  -50.716886      12.965063  397.039448                0.000000           0.217050            3       True         20
# 1   NeuralNetFastAI_BAG_L2  -52.392568      12.158018  389.859026                0.334090          20.687970            2       True         17
# 2   RandomForestMSE_BAG_L2  -53.028670      12.226212  374.557781                0.402284           5.386725            2       True         14
# 3     ExtraTreesMSE_BAG_L2  -54.024953      12.228688  370.747704                0.404760           1.576648            2       True         16
# 4          LightGBM_BAG_L2  -54.667035      12.026694  372.968209                0.202766           3.797153            2       True         13
# 5           XGBoost_BAG_L2  -54.921636      11.937957  375.573048                0.114029           6.401992            2       True         18
# 6          CatBoost_BAG_L2  -55.456502      11.868282  481.594696                0.044354         112.423640            2       True         15
# 7        LightGBMXT_BAG_L2  -61.517953      16.257257  379.500584                4.433330          10.329528            2       True         12
# 8    NeuralNetTorch_BAG_L2  -63.481691      12.119495  388.807302                0.295568          19.636246            2       True         19
# 9      WeightedEnsemble_L2  -84.146423       0.015626    0.302041                0.000000           0.261009            2       True         11
# 10   KNeighborsDist_BAG_L1  -84.146423       0.015626    0.041031                0.015626           0.041031            1       True          2
# 11   KNeighborsUnif_BAG_L1 -101.588176       0.015617    0.035099                0.015617           0.035099            1       True          1
# 12  RandomForestMSE_BAG_L1 -116.705026       0.365784    1.849526                0.365784           1.849526            1       True          5
# 13    ExtraTreesMSE_BAG_L1 -124.395497       0.407940    0.879705                0.407940           0.879705            1       True          7
# 14         LightGBM_BAG_L1 -130.339419       0.935308    4.580270                0.935308           4.580270            1       True          4
# 15          XGBoost_BAG_L1 -131.127673       0.169674    4.548104                0.169674           4.548104            1       True          9
# 16       LightGBMXT_BAG_L1 -131.159177       9.178683    9.561656                9.178683           9.561656            1       True          3
# 17         CatBoost_BAG_L1 -131.926344       0.098167  296.033499                0.098167         296.033499            1       True          6
# 18  NeuralNetFastAI_BAG_L1 -135.319839       0.377352   23.333002                0.377352          23.333002            1       True          8
# 19   NeuralNetTorch_BAG_L1 -140.735726       0.259778   28.309164                0.259778          28.309164            1       True         10
# Number of models trained: 20
# Types of models trained:
# {'WeightedEnsembleModel', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_RF'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])             : 3 | ['season', 'weather', 'weekday']
# ('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# ('int', [])                  : 1 | ['humidity']
# ('int', ['bool'])            : 2 | ['holiday', 'workingday']
# ('int', ['datetime_as_int']) : 5 | ['datetime', 'datetime.year', 'datetime.month', 'datetime.day', 'datetime.dayofweek']
# Plot summary of models saved to file: AutogluonModels/ag-20220902_205304\SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': -101.58817625927213,
#   'KNeighborsDist_BAG_L1': -84.14642264302962,
#   'LightGBMXT_BAG_L1': -131.15917742519977,
#   'LightGBM_BAG_L1': -130.33941896121698,
#   'RandomForestMSE_BAG_L1': -116.70502615707328,
#   'CatBoost_BAG_L1': -131.92634442307192,
#   'ExtraTreesMSE_BAG_L1': -124.39549706740807,
#   'NeuralNetFastAI_BAG_L1': -135.31983942340656,
#   'XGBoost_BAG_L1': -131.12767347991326,
#   'NeuralNetTorch_BAG_L1': -140.73572572538214,
#   'WeightedEnsemble_L2': -84.14642264302962,
#   'LightGBMXT_BAG_L2': -61.51795297528524,
#   'LightGBM_BAG_L2': -54.66703547112578,
#   'RandomForestMSE_BAG_L2': -53.02866973275555,
#   'CatBoost_BAG_L2': -55.45650232067446,
#   'ExtraTreesMSE_BAG_L2': -54.024953220620716,
#   'NeuralNetFastAI_BAG_L2': -52.39256757356605,
#   'XGBoost_BAG_L2': -54.921635618515275,
#   'NeuralNetTorch_BAG_L2': -63.48169127370948,
#   'WeightedEnsemble_L3': -50.71688601981009},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': 'AutogluonModels/ag-20220902_205304\\models\\KNeighborsUnif_BAG_L1\\',
#   'KNeighborsDist_BAG_L1': 'AutogluonModels/ag-20220902_205304\\models\\KNeighborsDist_BAG_L1\\',
#   'LightGBMXT_BAG_L1': 'AutogluonModels/ag-20220902_205304\\models\\LightGBMXT_BAG_L1\\',
#   'LightGBM_BAG_L1': 'AutogluonModels/ag-20220902_205304\\models\\LightGBM_BAG_L1\\',
#   'RandomForestMSE_BAG_L1': 'AutogluonModels/ag-20220902_205304\\models\\RandomForestMSE_BAG_L1\\',
#   'CatBoost_BAG_L1': 'AutogluonModels/ag-20220902_205304\\models\\CatBoost_BAG_L1\\',
#   'ExtraTreesMSE_BAG_L1': 'AutogluonModels/ag-20220902_205304\\models\\ExtraTreesMSE_BAG_L1\\',
#   'NeuralNetFastAI_BAG_L1': 'AutogluonModels/ag-20220902_205304\\models\\NeuralNetFastAI_BAG_L1\\',
#   'XGBoost_BAG_L1': 'AutogluonModels/ag-20220902_205304\\models\\XGBoost_BAG_L1\\',
#   'NeuralNetTorch_BAG_L1': 'AutogluonModels/ag-20220902_205304\\models\\NeuralNetTorch_BAG_L1\\',
#   'WeightedEnsemble_L2': 'AutogluonModels/ag-20220902_205304\\models\\WeightedEnsemble_L2\\',
#   'LightGBMXT_BAG_L2': 'AutogluonModels/ag-20220902_205304\\models\\LightGBMXT_BAG_L2\\',
#   'LightGBM_BAG_L2': 'AutogluonModels/ag-20220902_205304\\models\\LightGBM_BAG_L2\\',
#   'RandomForestMSE_BAG_L2': 'AutogluonModels/ag-20220902_205304\\models\\RandomForestMSE_BAG_L2\\',
#   'CatBoost_BAG_L2': 'AutogluonModels/ag-20220902_205304\\models\\CatBoost_BAG_L2\\',
#   'ExtraTreesMSE_BAG_L2': 'AutogluonModels/ag-20220902_205304\\models\\ExtraTreesMSE_BAG_L2\\',
#   'NeuralNetFastAI_BAG_L2': 'AutogluonModels/ag-20220902_205304\\models\\NeuralNetFastAI_BAG_L2\\',
#   'XGBoost_BAG_L2': 'AutogluonModels/ag-20220902_205304\\models\\XGBoost_BAG_L2\\',
#   'NeuralNetTorch_BAG_L2': 'AutogluonModels/ag-20220902_205304\\models\\NeuralNetTorch_BAG_L2\\',
#   'WeightedEnsemble_L3': 'AutogluonModels/ag-20220902_205304\\models\\WeightedEnsemble_L3\\'},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.03509926795959473,
#   'KNeighborsDist_BAG_L1': 0.0410311222076416,
#   'LightGBMXT_BAG_L1': 9.561656475067139,
#   'LightGBM_BAG_L1': 4.5802695751190186,
#   'RandomForestMSE_BAG_L1': 1.8495256900787354,
#   'CatBoost_BAG_L1': 296.0334994792938,
#   'ExtraTreesMSE_BAG_L1': 0.8797049522399902,
#   'NeuralNetFastAI_BAG_L1': 23.333001852035522,
#   'XGBoost_BAG_L1': 4.5481038093566895,
#   'NeuralNetTorch_BAG_L1': 28.309163808822632,
#   'WeightedEnsemble_L2': 0.26100945472717285,
#   'LightGBMXT_BAG_L2': 10.329528093338013,
#   'LightGBM_BAG_L2': 3.7971527576446533,
#   'RandomForestMSE_BAG_L2': 5.386724948883057,
#   'CatBoost_BAG_L2': 112.42363953590393,
#   'ExtraTreesMSE_BAG_L2': 1.5766477584838867,
#   'NeuralNetFastAI_BAG_L2': 20.68796968460083,
#   'XGBoost_BAG_L2': 6.401992082595825,
#   'NeuralNetTorch_BAG_L2': 19.63624596595764,
#   'WeightedEnsemble_L3': 0.21704959869384766},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.015616893768310547,
#   'KNeighborsDist_BAG_L1': 0.015625715255737305,
#   'LightGBMXT_BAG_L1': 9.178682804107666,
#   'LightGBM_BAG_L1': 0.9353079795837402,
#   'RandomForestMSE_BAG_L1': 0.3657839298248291,
#   'CatBoost_BAG_L1': 0.09816694259643555,
#   'ExtraTreesMSE_BAG_L1': 0.4079396724700928,
#   'NeuralNetFastAI_BAG_L1': 0.377352237701416,
#   'XGBoost_BAG_L1': 0.16967368125915527,
#   'NeuralNetTorch_BAG_L1': 0.2597777843475342,
#   'WeightedEnsemble_L2': 0.0,
#   'LightGBMXT_BAG_L2': 4.433329820632935,
#   'LightGBM_BAG_L2': 0.20276641845703125,
#   'RandomForestMSE_BAG_L2': 0.4022841453552246,
#   'CatBoost_BAG_L2': 0.04435443878173828,
#   'ExtraTreesMSE_BAG_L2': 0.40476036071777344,
#   'NeuralNetFastAI_BAG_L2': 0.3340904712677002,
#   'XGBoost_BAG_L2': 0.1140294075012207,
#   'NeuralNetTorch_BAG_L2': 0.29556775093078613,
#   'WeightedEnsemble_L3': 0.0},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                      model   score_val  pred_time_val    fit_time  \
#  0      WeightedEnsemble_L3  -50.716886      12.965063  397.039448
#  1   NeuralNetFastAI_BAG_L2  -52.392568      12.158018  389.859026
#  2   RandomForestMSE_BAG_L2  -53.028670      12.226212  374.557781
#  3     ExtraTreesMSE_BAG_L2  -54.024953      12.228688  370.747704
#  4          LightGBM_BAG_L2  -54.667035      12.026694  372.968209
#  5           XGBoost_BAG_L2  -54.921636      11.937957  375.573048
#  6          CatBoost_BAG_L2  -55.456502      11.868282  481.594696
#  7        LightGBMXT_BAG_L2  -61.517953      16.257257  379.500584
#  8    NeuralNetTorch_BAG_L2  -63.481691      12.119495  388.807302
#  9      WeightedEnsemble_L2  -84.146423       0.015626    0.302041
#  10   KNeighborsDist_BAG_L1  -84.146423       0.015626    0.041031
#  11   KNeighborsUnif_BAG_L1 -101.588176       0.015617    0.035099
#  12  RandomForestMSE_BAG_L1 -116.705026       0.365784    1.849526
#  13    ExtraTreesMSE_BAG_L1 -124.395497       0.407940    0.879705
#  14         LightGBM_BAG_L1 -130.339419       0.935308    4.580270
#  15          XGBoost_BAG_L1 -131.127673       0.169674    4.548104
#  16       LightGBMXT_BAG_L1 -131.159177       9.178683    9.561656
#  17         CatBoost_BAG_L1 -131.926344       0.098167  296.033499
#  18  NeuralNetFastAI_BAG_L1 -135.319839       0.377352   23.333002
#  19   NeuralNetTorch_BAG_L1 -140.735726       0.259778   28.309164
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.000000           0.217050            3       True
#  1                 0.334090          20.687970            2       True
#  2                 0.402284           5.386725            2       True
#  3                 0.404760           1.576648            2       True
#  4                 0.202766           3.797153            2       True
#  5                 0.114029           6.401992            2       True
#  6                 0.044354         112.423640            2       True
#  7                 4.433330          10.329528            2       True
#  8                 0.295568          19.636246            2       True
#  9                 0.000000           0.261009            2       True
#  10                0.015626           0.041031            1       True
#  11                0.015617           0.035099            1       True
#  12                0.365784           1.849526            1       True
#  13                0.407940           0.879705            1       True
#  14                0.935308           4.580270            1       True
#  15                0.169674           4.548104            1       True
#  16                9.178683           9.561656            1       True
#  17                0.098167         296.033499            1       True
#  18                0.377352          23.333002            1       True
#  19                0.259778          28.309164            1       True
#
#      fit_order
#  0          20
#  1          17
#  2          14
#  3          16
#  4          13
#  5          18
#  6          15
#  7          12
#  8          19
#  9          11
#  10          2
#  11          1
#  12          5
#  13          7
#  14          4
#  15          9
#  16          3
#  17          6
#  18          8
#  19         10  }

# %%
predictions =predictor_new_features.predict(test)

predictions.head()
# Out:
# C:\Users\Lenovo\anaconda3\envs\myenv\lib\site-packages\xgboost\compat.py:31: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# 0    21.664917
# 1    38.891357
# 2    44.282181
# 3    46.112419
# 4    48.258797
# Name: count, dtype: float32

# %%
predictions.describe()
# Out:
# count    6493.000000
# mean       99.635452
# std        88.495079
# min        -2.982982
# 25%        22.031036
# 50%        68.172020
# 75%       166.278473
# max       355.339722
# Name: count, dtype: float64

# %%
# Remember to set all negative values to zero
b=np.array(predictions)
print(sum(b<0))
# Out:
# 37

# %%
predictions=np.where(predictions < 0.0, 0, predictions)

# %%
b=np.array(predictions)
print(sum(b<0))
# Out:
# 0

# %%
submission_new_features= pd.read_csv('data/sampleSubmission.csv')

# %%
# Same submitting predictions
submission_new_features["count"] = predictions
submission_new_features.to_csv("submission_new_features.csv", index=False)

# %%
# !kaggle competitions submit -c bike-sharing-demand -f submission_new_features.csv -m "new features"
# Out:
# Successfully submitted to Bike Sharing Demand
#   0%|          | 0.00/195k [00:00<?, ?B/s]
#   4%|4         | 8.00k/195k [00:00<00:06, 27.8kB/s]
#  41%|####1     | 80.0k/195k [00:00<00:00, 181kB/s]
#  53%|#####3    | 104k/195k [00:01<00:01, 64.8kB/s]
#  99%|#########8| 192k/195k [00:01<00:00, 143kB/s]
# 100%|##########| 195k/195k [00:11<00:00, 17.2kB/s]

# %%
# !kaggle competitions submissions -c bike-sharing-demand | tail -n +1 | head -n 6
# Out:
# 'tail' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# #### New Score of `1.82964`

# %%
test.to_csv('data/test_newf.csv',index=False)

# %%
train.to_csv('data/train_newf.csv',index=False)

# %% [markdown]
# ## Step 6: Hyper parameter optimization
# * There are many options for hyper parameter optimization.
# * Options are to change the AutoGluon higher level parameters or the individual model hyperparameters.
# * The hyperparameters of the models themselves that are in AutoGluon. Those need the `hyperparameter` and `hyperparameter_tune_kwargs` arguments.

# %%
train=pd.read_csv('data/train_newf.csv')
test=pd.read_csv('data/test_newf.csv')

# %%
nn_options = {
    'num_epochs': 10,
    'learning_rate': ag.space.Real(1e-4, 1e-2, default=5e-4, log=True),
    'activation': ag.space.Categorical('relu', 'softrelu', 'tanh'),  
    'dropout_prob': ag.space.Real(0.0, 0.5, default=0.1),
}

gbm_options = {  
    'num_boost_round': 100, 
    'num_leaves': ag.space.Int(lower=26, upper=66, default=36),
}
search_strategy = 'auto'
num_trials = 5
hyperparameters={'GBM': gbm_options,'NN_TORCH': nn_options}
hyperparameter_tune_kwargs = {'num_trials': num_trials,'scheduler' : 'local','searcher': search_strategy,}

# %%
predictor_new_hpo =TabularPredictor(label='count', eval_metric='root_mean_squared_error').fit(train, time_limit= 10*60, presets="best_quality", hyperparameters=hyperparameters, hyperparameter_tune_kwargs=hyperparameter_tune_kwargs)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20220902_235826\"
# Presets specified: ['best_quality']
# Warning: hyperparameter tuning is currently experimental and may cause the process to hang.
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 600s
# AutoGluon will save models to "AutogluonModels/ag-20220902_235826\"
# AutoGluon Version:  0.5.2
# Python Version:     3.9.12
# Operating System:   Windows
# Train Data Rows:    10886
# Train Data Columns: 10
# Label Column: count
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == int and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (977, 1, 191.57413, 181.14445)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    6956.05 MB
# 	Train Data (Original)  Memory Usage: 1.61 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 2 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])                        : 6 | ['season', 'holiday', 'workingday', 'weather', 'humidity', ...]
# 		('object', ['datetime_as_object']) : 1 | ['datetime']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])                  : 4 | ['season', 'weather', 'humidity', 'weekday']
# 		('int', ['bool'])            : 2 | ['holiday', 'workingday']
# 		('int', ['datetime_as_int']) : 5 | ['datetime', 'datetime.year', 'datetime.month', 'datetime.day', 'datetime.dayofweek']
# 	0.1s = Fit runtime
# 	10 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.89 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 2 L1 models ...
# Hyperparameter tuning model: LightGBM_BAG_L1 ... Tuning model for up to 22.49s of the 599.92s of remaining time.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Fitted model: LightGBM_BAG_L1\T1 ...
# 	-133.9704	 = Validation score   (-root_mean_squared_error)
# 	0.67s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitted model: LightGBM_BAG_L1\T2 ...
# 	-133.4989	 = Validation score   (-root_mean_squared_error)
# 	0.12s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitted model: LightGBM_BAG_L1\T3 ...
# 	-132.2531	 = Validation score   (-root_mean_squared_error)
# 	0.19s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitted model: LightGBM_BAG_L1\T4 ...
# 	-154.5706	 = Validation score   (-root_mean_squared_error)
# 	0.17s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitted model: LightGBM_BAG_L1\T5 ...
# 	-133.5398	 = Validation score   (-root_mean_squared_error)
# 	0.17s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Hyperparameter tuning model: NeuralNetTorch_BAG_L1 ... Tuning model for up to 22.49s of the 598.19s of remaining time.
# 2022-09-03 01:58:34,278	ERROR syncer.py:147 -- Log sync requires rsync to be installed.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# NaN or Inf found in input tensor.
# Fitting model: LightGBM_BAG_L1\T1 ... Training model for up to 383.97s of the 584.05s of remaining time.
# 	Fitting 7 child models (S1F2 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.4732	 = Validation score   (-root_mean_squared_error)
# 	1.87s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T2 ... Training model for up to 379.92s of the 579.99s of remaining time.
# 	Fitting 7 child models (S1F2 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.062	 = Validation score   (-root_mean_squared_error)
# 	1.33s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T3 ... Training model for up to 373.87s of the 573.94s of remaining time.
# 	Fitting 7 child models (S1F2 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.1234	 = Validation score   (-root_mean_squared_error)
# 	2.62s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T4 ... Training model for up to 368.22s of the 568.29s of remaining time.
# 	Fitting 7 child models (S1F2 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.9652	 = Validation score   (-root_mean_squared_error)
# 	2.35s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T5 ... Training model for up to 362.94s of the 563.01s of remaining time.
# 	Fitting 7 child models (S1F2 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.8841	 = Validation score   (-root_mean_squared_error)
# 	2.33s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Fitting model: LightGBM_BAG_L1\T1 ... Training model for up to 357.86s of the 557.93s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.9455	 = Validation score   (-root_mean_squared_error)
# 	4.2s	 = Training   runtime
# 	0.12s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T2 ... Training model for up to 352.56s of the 552.64s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.4869	 = Validation score   (-root_mean_squared_error)
# 	3.61s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T3 ... Training model for up to 347.14s of the 547.21s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-133.6345	 = Validation score   (-root_mean_squared_error)
# 	4.84s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T4 ... Training model for up to 341.57s of the 541.64s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.8443	 = Validation score   (-root_mean_squared_error)
# 	4.51s	 = Training   runtime
# 	0.1s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T5 ... Training model for up to 336.21s of the 536.28s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.5258	 = Validation score   (-root_mean_squared_error)
# 	5.27s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: LightGBM_BAG_L1\T1 ... Training model for up to 329.81s of the 529.88s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.848	 = Validation score   (-root_mean_squared_error)
# 	6.98s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T2 ... Training model for up to 323.56s of the 523.63s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.3903	 = Validation score   (-root_mean_squared_error)
# 	6.25s	 = Training   runtime
# 	0.18s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T3 ... Training model for up to 317.29s of the 517.36s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-133.5276	 = Validation score   (-root_mean_squared_error)
# 	7.67s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T4 ... Training model for up to 310.83s of the 510.9s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.8211	 = Validation score   (-root_mean_squared_error)
# 	7.01s	 = Training   runtime
# 	0.15s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T5 ... Training model for up to 304.71s of the 504.79s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.3972	 = Validation score   (-root_mean_squared_error)
# 	8.14s	 = Training   runtime
# 	0.21s	 = Validation runtime
# Repeating k-fold bagging: 4/20
# Fitting model: LightGBM_BAG_L1\T1 ... Training model for up to 298.27s of the 498.34s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.8242	 = Validation score   (-root_mean_squared_error)
# 	9.73s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T2 ... Training model for up to 292.04s of the 492.11s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.3443	 = Validation score   (-root_mean_squared_error)
# 	8.8s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T3 ... Training model for up to 285.75s of the 485.82s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-133.5299	 = Validation score   (-root_mean_squared_error)
# 	10.54s	 = Training   runtime
# 	0.37s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T4 ... Training model for up to 279.38s of the 479.46s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.824	 = Validation score   (-root_mean_squared_error)
# 	9.79s	 = Training   runtime
# 	0.2s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T5 ... Training model for up to 272.38s of the 472.46s of remaining time.
# 	Fitting 8 child models (S4F1 - S4F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.3758	 = Validation score   (-root_mean_squared_error)
# 	10.68s	 = Training   runtime
# 	0.27s	 = Validation runtime
# Repeating k-fold bagging: 5/20
# Fitting model: LightGBM_BAG_L1\T1 ... Training model for up to 266.39s of the 466.46s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.7689	 = Validation score   (-root_mean_squared_error)
# 	12.47s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T2 ... Training model for up to 260.44s of the 460.51s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.2628	 = Validation score   (-root_mean_squared_error)
# 	11.58s	 = Training   runtime
# 	0.34s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T3 ... Training model for up to 253.85s of the 453.92s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-133.4402	 = Validation score   (-root_mean_squared_error)
# 	13.43s	 = Training   runtime
# 	0.47s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T4 ... Training model for up to 247.13s of the 447.21s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.8038	 = Validation score   (-root_mean_squared_error)
# 	12.46s	 = Training   runtime
# 	0.26s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T5 ... Training model for up to 240.88s of the 440.96s of remaining time.
# 	Fitting 8 child models (S5F1 - S5F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.3066	 = Validation score   (-root_mean_squared_error)
# 	13.36s	 = Training   runtime
# 	0.35s	 = Validation runtime
# Repeating k-fold bagging: 6/20
# Fitting model: LightGBM_BAG_L1\T1 ... Training model for up to 234.63s of the 434.7s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.8102	 = Validation score   (-root_mean_squared_error)
# 	15.24s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T2 ... Training model for up to 228.31s of the 428.39s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.2812	 = Validation score   (-root_mean_squared_error)
# 	14.34s	 = Training   runtime
# 	0.41s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T3 ... Training model for up to 221.88s of the 421.95s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-133.5147	 = Validation score   (-root_mean_squared_error)
# 	16.21s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T4 ... Training model for up to 215.41s of the 415.48s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.8072	 = Validation score   (-root_mean_squared_error)
# 	15.35s	 = Training   runtime
# 	0.32s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T5 ... Training model for up to 209.0s of the 409.07s of remaining time.
# 	Fitting 8 child models (S6F1 - S6F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.3493	 = Validation score   (-root_mean_squared_error)
# 	16.27s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Repeating k-fold bagging: 7/20
# Fitting model: LightGBM_BAG_L1\T1 ... Training model for up to 202.6s of the 402.67s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.7637	 = Validation score   (-root_mean_squared_error)
# 	18.42s	 = Training   runtime
# 	0.56s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T2 ... Training model for up to 195.85s of the 395.92s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.2579	 = Validation score   (-root_mean_squared_error)
# 	16.88s	 = Training   runtime
# 	0.46s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T3 ... Training model for up to 189.53s of the 389.6s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-133.4672	 = Validation score   (-root_mean_squared_error)
# 	18.92s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T4 ... Training model for up to 183.24s of the 383.31s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.7835	 = Validation score   (-root_mean_squared_error)
# 	18.56s	 = Training   runtime
# 	0.38s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T5 ... Training model for up to 176.67s of the 376.75s of remaining time.
# 	Fitting 8 child models (S7F1 - S7F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.2991	 = Validation score   (-root_mean_squared_error)
# 	19.01s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Repeating k-fold bagging: 8/20
# Fitting model: LightGBM_BAG_L1\T1 ... Training model for up to 170.15s of the 370.23s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.742	 = Validation score   (-root_mean_squared_error)
# 	21.1s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T2 ... Training model for up to 163.7s of the 363.77s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.2641	 = Validation score   (-root_mean_squared_error)
# 	19.6s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T3 ... Training model for up to 157.44s of the 357.52s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-133.4622	 = Validation score   (-root_mean_squared_error)
# 	21.89s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T4 ... Training model for up to 150.9s of the 350.98s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.789	 = Validation score   (-root_mean_squared_error)
# 	21.27s	 = Training   runtime
# 	0.45s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T5 ... Training model for up to 144.58s of the 344.65s of remaining time.
# 	Fitting 8 child models (S8F1 - S8F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.2813	 = Validation score   (-root_mean_squared_error)
# 	21.81s	 = Training   runtime
# 	0.59s	 = Validation runtime
# Repeating k-fold bagging: 9/20
# Fitting model: LightGBM_BAG_L1\T1 ... Training model for up to 138.3s of the 338.37s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.7168	 = Validation score   (-root_mean_squared_error)
# 	24.0s	 = Training   runtime
# 	0.71s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T2 ... Training model for up to 131.85s of the 331.93s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.2327	 = Validation score   (-root_mean_squared_error)
# 	22.72s	 = Training   runtime
# 	0.6s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T3 ... Training model for up to 125.38s of the 325.46s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-133.4218	 = Validation score   (-root_mean_squared_error)
# 	24.72s	 = Training   runtime
# 	0.9s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T4 ... Training model for up to 118.78s of the 318.85s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.7838	 = Validation score   (-root_mean_squared_error)
# 	23.93s	 = Training   runtime
# 	0.51s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T5 ... Training model for up to 112.45s of the 312.52s of remaining time.
# 	Fitting 8 child models (S9F1 - S9F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.2662	 = Validation score   (-root_mean_squared_error)
# 	24.65s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Repeating k-fold bagging: 10/20
# Fitting model: LightGBM_BAG_L1\T1 ... Training model for up to 106.15s of the 306.22s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.6817	 = Validation score   (-root_mean_squared_error)
# 	26.79s	 = Training   runtime
# 	0.79s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T2 ... Training model for up to 99.89s of the 299.97s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.2263	 = Validation score   (-root_mean_squared_error)
# 	25.55s	 = Training   runtime
# 	0.66s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T3 ... Training model for up to 93.47s of the 293.54s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-133.3851	 = Validation score   (-root_mean_squared_error)
# 	27.57s	 = Training   runtime
# 	0.99s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T4 ... Training model for up to 87.05s of the 287.12s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.7665	 = Validation score   (-root_mean_squared_error)
# 	26.64s	 = Training   runtime
# 	0.58s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T5 ... Training model for up to 80.84s of the 280.91s of remaining time.
# 	Fitting 8 child models (S10F1 - S10F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.2275	 = Validation score   (-root_mean_squared_error)
# 	27.42s	 = Training   runtime
# 	0.76s	 = Validation runtime
# Repeating k-fold bagging: 11/20
# Fitting model: LightGBM_BAG_L1\T1 ... Training model for up to 74.38s of the 274.45s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.7092	 = Validation score   (-root_mean_squared_error)
# 	29.67s	 = Training   runtime
# 	0.86s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T2 ... Training model for up to 67.95s of the 268.03s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.2541	 = Validation score   (-root_mean_squared_error)
# 	28.42s	 = Training   runtime
# 	0.73s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T3 ... Training model for up to 61.44s of the 261.52s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-133.3797	 = Validation score   (-root_mean_squared_error)
# 	30.42s	 = Training   runtime
# 	1.08s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T4 ... Training model for up to 55.02s of the 255.09s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-155.7651	 = Validation score   (-root_mean_squared_error)
# 	29.41s	 = Training   runtime
# 	0.63s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1\T5 ... Training model for up to 48.5s of the 248.57s of remaining time.
# 	Fitting 8 child models (S11F1 - S11F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.2255	 = Validation score   (-root_mean_squared_error)
# 	30.21s	 = Training   runtime
# 	0.85s	 = Validation runtime
# Completed 11/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.0s of the 242.15s of remaining time.
# 	-133.3793	 = Validation score   (-root_mean_squared_error)
# 	0.16s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 2 L2 models ...
# Hyperparameter tuning model: LightGBM_BAG_L2 ... Tuning model for up to 13.61s of the 241.98s of remaining time.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Fitted model: LightGBM_BAG_L2\T1 ...
# 	-126.6909	 = Validation score   (-root_mean_squared_error)
# 	0.21s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitted model: LightGBM_BAG_L2\T2 ...
# 	-126.0667	 = Validation score   (-root_mean_squared_error)
# 	0.22s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitted model: LightGBM_BAG_L2\T3 ...
# 	-127.5524	 = Validation score   (-root_mean_squared_error)
# 	0.55s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitted model: LightGBM_BAG_L2\T4 ...
# 	-145.0584	 = Validation score   (-root_mean_squared_error)
# 	0.27s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitted model: LightGBM_BAG_L2\T5 ...
# 	-127.0541	 = Validation score   (-root_mean_squared_error)
# 	0.24s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Hyperparameter tuning model: NeuralNetTorch_BAG_L2 ... Tuning model for up to 13.61s of the 240.11s of remaining time.
# NaN or Inf found in input tensor.
# 2022-09-03 02:04:38,192	INFO stopper.py:363 -- Reached timeout of 10.889162925481799 seconds. Stopping all trials.
# Fitted model: NeuralNetTorch_BAG_L2\T1 ...
# 	-132.9827	 = Validation score   (-root_mean_squared_error)
# 	4.79s	 = Training   runtime
# 	0.04s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2\T1 ... Training model for up to 227.57s of the 227.57s of remaining time.
# 	Fitting 7 child models (S1F2 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.7245	 = Validation score   (-root_mean_squared_error)
# 	2.35s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2\T2 ... Training model for up to 222.42s of the 222.41s of remaining time.
# 	Fitting 7 child models (S1F2 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.4862	 = Validation score   (-root_mean_squared_error)
# 	2.56s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2\T3 ... Training model for up to 216.58s of the 216.58s of remaining time.
# 	Fitting 7 child models (S1F2 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-132.1139	 = Validation score   (-root_mean_squared_error)
# 	3.26s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2\T4 ... Training model for up to 210.51s of the 210.5s of remaining time.
# 	Fitting 7 child models (S1F2 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-148.4652	 = Validation score   (-root_mean_squared_error)
# 	2.69s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2\T5 ... Training model for up to 204.69s of the 204.68s of remaining time.
# 	Fitting 7 child models (S1F2 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-132.1416	 = Validation score   (-root_mean_squared_error)
# 	2.78s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2\T1 ... Training model for up to 198.7s of the 198.69s of remaining time.
# 	Fitting 7 child models (S1F2 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-135.6083	 = Validation score   (-root_mean_squared_error)
# 	22.99s	 = Training   runtime
# 	0.33s	 = Validation runtime
# Repeating k-fold bagging: 2/20
# Fitting model: LightGBM_BAG_L2\T1 ... Training model for up to 177.18s of the 177.17s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.4404	 = Validation score   (-root_mean_squared_error)
# 	5.04s	 = Training   runtime
# 	0.13s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2\T2 ... Training model for up to 170.68s of the 170.68s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.1232	 = Validation score   (-root_mean_squared_error)
# 	5.21s	 = Training   runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2\T3 ... Training model for up to 164.24s of the 164.24s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.5465	 = Validation score   (-root_mean_squared_error)
# 	6.22s	 = Training   runtime
# 	0.44s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2\T4 ... Training model for up to 157.39s of the 157.39s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-148.4604	 = Validation score   (-root_mean_squared_error)
# 	5.27s	 = Training   runtime
# 	0.11s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2\T5 ... Training model for up to 151.05s of the 151.04s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.7546	 = Validation score   (-root_mean_squared_error)
# 	5.64s	 = Training   runtime
# 	0.17s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2\T1 ... Training model for up to 144.28s of the 144.27s of remaining time.
# 	Fitting 8 child models (S2F1 - S2F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.6157	 = Validation score   (-root_mean_squared_error)
# 	41.84s	 = Training   runtime
# 	0.67s	 = Validation runtime
# Repeating k-fold bagging: 3/20
# Fitting model: LightGBM_BAG_L2\T1 ... Training model for up to 121.63s of the 121.63s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.3466	 = Validation score   (-root_mean_squared_error)
# 	7.74s	 = Training   runtime
# 	0.19s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2\T2 ... Training model for up to 114.8s of the 114.79s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-130.9114	 = Validation score   (-root_mean_squared_error)
# 	7.98s	 = Training   runtime
# 	0.14s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2\T3 ... Training model for up to 108.22s of the 108.21s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.4225	 = Validation score   (-root_mean_squared_error)
# 	9.17s	 = Training   runtime
# 	0.54s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2\T4 ... Training model for up to 101.63s of the 101.63s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-148.4635	 = Validation score   (-root_mean_squared_error)
# 	7.88s	 = Training   runtime
# 	0.16s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2\T5 ... Training model for up to 95.11s of the 95.1s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-131.6641	 = Validation score   (-root_mean_squared_error)
# 	8.65s	 = Training   runtime
# 	0.25s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2\T1 ... Training model for up to 88.44s of the 88.44s of remaining time.
# 	Fitting 8 child models (S3F1 - S3F8) | Fitting with ParallelLocalFoldFittingStrategy
# 	-134.3344	 = Validation score   (-root_mean_squared_error)
# 	61.8s	 = Training   runtime
# 	1.01s	 = Validation runtime
# Completed 3/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the 64.74s of remaining time.
# 	-130.8507	 = Validation score   (-root_mean_squared_error)
# 	0.17s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 535.75s ... Best model: "WeightedEnsemble_L3"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/ag-20220902_235826\")

# %%
predictor_new_hpo.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                        model   score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0        WeightedEnsemble_L3 -130.850674       5.842651  227.239566                0.001000           0.169149            3       True         13
# 1         LightGBM_BAG_L2\T2 -130.911450       4.293290  156.100158                0.137603           7.978801            2       True          8
# 2         LightGBM_BAG_L2\T1 -131.346579       4.349871  155.865875                0.194184           7.744517            2       True          7
# 3         LightGBM_BAG_L2\T3 -131.422480       4.697021  157.296209                0.541333           9.174851            2       True          9
# 4         LightGBM_BAG_L2\T5 -131.664086       4.401690  156.766960                0.246003           8.645602            2       True         11
# 5        WeightedEnsemble_L2 -133.379265       1.815723   58.994343                0.001000           0.155984            2       True          6
# 6         LightGBM_BAG_L1\T3 -133.379651       1.084550   30.420599                1.084550          30.420599            1       True          3
# 7         LightGBM_BAG_L1\T2 -134.254126       0.730172   28.417760                0.730172          28.417760            1       True          2
# 8   NeuralNetTorch_BAG_L2\T1 -134.334384       5.162714  209.916765                1.007027          61.795407            2       True         12
# 9         LightGBM_BAG_L1\T1 -134.709186       0.855677   29.671609                0.855677          29.671609            1       True          1
# 10        LightGBM_BAG_L1\T5 -135.225529       0.850456   30.205107                0.850456          30.205107            1       True          5
# 11        LightGBM_BAG_L2\T4 -148.463475       4.318447  156.000533                0.162760           7.879175            2       True         10
# 12        LightGBM_BAG_L1\T4 -155.765120       0.634832   29.406282                0.634832          29.406282            1       True          4
# Number of models trained: 13
# Types of models trained:
# {'StackerEnsembleModel_LGB', 'WeightedEnsembleModel', 'StackerEnsembleModel_TabularNeuralNetTorch'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])                : 3 | ['temp', 'atemp', 'windspeed']
# ('int', [])                  : 4 | ['season', 'weather', 'humidity', 'weekday']
# ('int', ['bool'])            : 2 | ['holiday', 'workingday']
# ('int', ['datetime_as_int']) : 5 | ['datetime', 'datetime.year', 'datetime.month', 'datetime.day', 'datetime.dayofweek']
# Plot summary of models saved to file: AutogluonModels/ag-20220902_235826\SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'LightGBM_BAG_L1\\T1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1\\T2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1\\T3': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1\\T4': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1\\T5': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBM_BAG_L2\\T1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2\\T2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2\\T3': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2\\T4': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2\\T5': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_BAG_L2\\T1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'LightGBM_BAG_L1\\T1': -134.70918615840907,
#   'LightGBM_BAG_L1\\T2': -134.25412584173412,
#   'LightGBM_BAG_L1\\T3': -133.3796514831482,
#   'LightGBM_BAG_L1\\T4': -155.7651197641718,
#   'LightGBM_BAG_L1\\T5': -135.22552923527724,
#   'WeightedEnsemble_L2': -133.37926535988987,
#   'LightGBM_BAG_L2\\T1': -131.34657885506633,
#   'LightGBM_BAG_L2\\T2': -130.9114495091064,
#   'LightGBM_BAG_L2\\T3': -131.42247986086258,
#   'LightGBM_BAG_L2\\T4': -148.46347515546304,
#   'LightGBM_BAG_L2\\T5': -131.66408625199654,
#   'NeuralNetTorch_BAG_L2\\T1': -134.33438388130327,
#   'WeightedEnsemble_L3': -130.85067409116348},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'LightGBM_BAG_L1\\T1': 'AutogluonModels/ag-20220902_235826\\models\\LightGBM_BAG_L1\\T1\\',
#   'LightGBM_BAG_L1\\T2': 'AutogluonModels/ag-20220902_235826\\models\\LightGBM_BAG_L1\\T2\\',
#   'LightGBM_BAG_L1\\T3': 'AutogluonModels/ag-20220902_235826\\models\\LightGBM_BAG_L1\\T3\\',
#   'LightGBM_BAG_L1\\T4': 'AutogluonModels/ag-20220902_235826\\models\\LightGBM_BAG_L1\\T4\\',
#   'LightGBM_BAG_L1\\T5': 'AutogluonModels/ag-20220902_235826\\models\\LightGBM_BAG_L1\\T5\\',
#   'WeightedEnsemble_L2': 'AutogluonModels/ag-20220902_235826\\models\\WeightedEnsemble_L2\\',
#   'LightGBM_BAG_L2\\T1': 'AutogluonModels/ag-20220902_235826\\models\\LightGBM_BAG_L2\\T1\\',
#   'LightGBM_BAG_L2\\T2': 'AutogluonModels/ag-20220902_235826\\models\\LightGBM_BAG_L2\\T2\\',
#   'LightGBM_BAG_L2\\T3': 'AutogluonModels/ag-20220902_235826\\models\\LightGBM_BAG_L2\\T3\\',
#   'LightGBM_BAG_L2\\T4': 'AutogluonModels/ag-20220902_235826\\models\\LightGBM_BAG_L2\\T4\\',
#   'LightGBM_BAG_L2\\T5': 'AutogluonModels/ag-20220902_235826\\models\\LightGBM_BAG_L2\\T5\\',
#   'NeuralNetTorch_BAG_L2\\T1': 'AutogluonModels/ag-20220902_235826\\models\\NeuralNetTorch_BAG_L2\\T1\\',
#   'WeightedEnsemble_L3': 'AutogluonModels/ag-20220902_235826\\models\\WeightedEnsemble_L3\\'},
#  'model_fit_times': {'LightGBM_BAG_L1\\T1': 29.67160940170288,
#   'LightGBM_BAG_L1\\T2': 28.417760372161865,
#   'LightGBM_BAG_L1\\T3': 30.42059850692749,
#   'LightGBM_BAG_L1\\T4': 29.40628218650818,
#   'LightGBM_BAG_L1\\T5': 30.20510697364807,
#   'WeightedEnsemble_L2': 0.15598440170288086,
#   'LightGBM_BAG_L2\\T1': 7.7445173263549805,
#   'LightGBM_BAG_L2\\T2': 7.9788007736206055,
#   'LightGBM_BAG_L2\\T3': 9.174851417541504,
#   'LightGBM_BAG_L2\\T4': 7.879175186157227,
#   'LightGBM_BAG_L2\\T5': 8.645602464675903,
#   'NeuralNetTorch_BAG_L2\\T1': 61.79540729522705,
#   'WeightedEnsemble_L3': 0.16914892196655273},
#  'model_pred_times': {'LightGBM_BAG_L1\\T1': 0.8556768894195557,
#   'LightGBM_BAG_L1\\T2': 0.7301723957061768,
#   'LightGBM_BAG_L1\\T3': 1.084550380706787,
#   'LightGBM_BAG_L1\\T4': 0.6348316669464111,
#   'LightGBM_BAG_L1\\T5': 0.8504557609558105,
#   'WeightedEnsemble_L2': 0.0010001659393310547,
#   'LightGBM_BAG_L2\\T1': 0.1941843032836914,
#   'LightGBM_BAG_L2\\T2': 0.1376030445098877,
#   'LightGBM_BAG_L2\\T3': 0.5413334369659424,
#   'LightGBM_BAG_L2\\T4': 0.16276025772094727,
#   'LightGBM_BAG_L2\\T5': 0.2460026741027832,
#   'NeuralNetTorch_BAG_L2\\T1': 1.0070269107818604,
#   'WeightedEnsemble_L3': 0.0010001659393310547},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'model_hyperparams': {'LightGBM_BAG_L1\\T1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1\\T2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1\\T3': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1\\T4': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1\\T5': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2\\T1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2\\T2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2\\T3': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2\\T4': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2\\T5': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2\\T1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                        model   score_val  pred_time_val    fit_time  \
#  0        WeightedEnsemble_L3 -130.850674       5.842651  227.239566
#  1         LightGBM_BAG_L2\T2 -130.911450       4.293290  156.100158
#  2         LightGBM_BAG_L2\T1 -131.346579       4.349871  155.865875
#  3         LightGBM_BAG_L2\T3 -131.422480       4.697021  157.296209
#  4         LightGBM_BAG_L2\T5 -131.664086       4.401690  156.766960
#  5        WeightedEnsemble_L2 -133.379265       1.815723   58.994343
#  6         LightGBM_BAG_L1\T3 -133.379651       1.084550   30.420599
#  7         LightGBM_BAG_L1\T2 -134.254126       0.730172   28.417760
#  8   NeuralNetTorch_BAG_L2\T1 -134.334384       5.162714  209.916765
#  9         LightGBM_BAG_L1\T1 -134.709186       0.855677   29.671609
#  10        LightGBM_BAG_L1\T5 -135.225529       0.850456   30.205107
#  11        LightGBM_BAG_L2\T4 -148.463475       4.318447  156.000533
#  12        LightGBM_BAG_L1\T4 -155.765120       0.634832   29.406282
#
#      pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
#  0                 0.001000           0.169149            3       True
#  1                 0.137603           7.978801            2       True
#  2                 0.194184           7.744517            2       True
#  3                 0.541333           9.174851            2       True
#  4                 0.246003           8.645602            2       True
#  5                 0.001000           0.155984            2       True
#  6                 1.084550          30.420599            1       True
#  7                 0.730172          28.417760            1       True
#  8                 1.007027          61.795407            2       True
#  9                 0.855677          29.671609            1       True
#  10                0.850456          30.205107            1       True
#  11                0.162760           7.879175            2       True
#  12                0.634832          29.406282            1       True
#
#      fit_order
#  0          13
#  1           8
#  2           7
#  3           9
#  4          11
#  5           6
#  6           3
#  7           2
#  8          12
#  9           1
#  10          5
#  11         10
#  12          4  }

# %%
predictions_new_hpo=predictor_new_hpo.predict(test)
predictions_new_hpo.head()
# Out:
# 0    71.008919
# 1    51.676960
# 2    51.676960
# 3    63.548096
# 4    63.548092
# Name: count, dtype: float32

# %%
predictions_new_hpo.describe()
# Out:
# count    6493.000000
# mean      197.187607
# std       121.983383
# min        29.506687
# 25%       111.334335
# 50%       162.022858
# 75%       270.015839
# max       620.350769
# Name: count, dtype: float64

# %% [markdown]
# # No negetive values

# %%
# Same submitting predictions
submission_new_hpo= pd.read_csv('data/sampleSubmission.csv')
submission_new_hpo["count"] = predictions_new_hpo
submission_new_hpo.to_csv("submission_new_hpo.csv", index=False)

# %%
# !kaggle competitions submit -c bike-sharing-demand -f submission_new_hpo.csv -m "new features with hyperparameters"
# Out:
# Successfully submitted to Bike Sharing Demand
#   0%|          | 0.00/195k [00:00<?, ?B/s]2022-09-03 02:08:26,772 WARNING Retrying (Retry(total=9, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001FFF61728E0>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed')': /upload/storage/v1/b/kaggle-competitions-submissions/o?uploadType=resumable&upload_id=ADPycduSpLaMAqfuBKOI3bBncOUxwk-bStmxSArKVLnVqjvFFxfLSDgpekD9L_6AJmndgPoWefQ9_VEOjYpumu1vP9PzSKs_SjbR
# 2022-09-03 02:08:27,781 WARNING Retrying (Retry(total=8, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001FFF6172AC0>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed')': /upload/storage/v1/b/kaggle-competitions-submissions/o?uploadType=resumable&upload_id=ADPycduSpLaMAqfuBKOI3bBncOUxwk-bStmxSArKVLnVqjvFFxfLSDgpekD9L_6AJmndgPoWefQ9_VEOjYpumu1vP9PzSKs_SjbR
# 2022-09-03 02:08:29,786 WARNING Retrying (Retry(total=7, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001FFF6172CA0>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed')': /upload/storage/v1/b/kaggle-competitions-submissions/o?uploadType=resumable&upload_id=ADPycduSpLaMAqfuBKOI3bBncOUxwk-bStmxSArKVLnVqjvFFxfLSDgpekD9L_6AJmndgPoWefQ9_VEOjYpumu1vP9PzSKs_SjbR
# 2022-09-03 02:08:33,791 WARNING Retrying (Retry(total=6, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001FFF6172E80>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed')': /upload/storage/v1/b/kaggle-competitions-submissions/o?uploadType=resumable&upload_id=ADPycduSpLaMAqfuBKOI3bBncOUxwk-bStmxSArKVLnVqjvFFxfLSDgpekD9L_6AJmndgPoWefQ9_VEOjYpumu1vP9PzSKs_SjbR
#
#   4%|4         | 8.00k/195k [00:07<03:00, 1.06kB/s]
#  45%|####5     | 88.0k/195k [00:07<00:06, 15.9kB/s]
#  70%|######9   | 136k/195k [00:08<00:02, 27.2kB/s]
# 100%|##########| 195k/195k [00:08<00:00, 45.9kB/s]
# 100%|##########| 195k/195k [00:12<00:00, 16.6kB/s]

# %%
# !kaggle competitions submissions -c bike-sharing-demand | tail -n +1 | head -n 6

# %% [markdown]
# #### New Score of `1.31684`

# %% [markdown]
# ## Step 7: Write a Report
# ### Refer to the markdown file for the full report
# ### Creating plots and table for report

# %%
# Taking the top model score from each training run and creating a line plot to show improvement
# You can create these in the notebook and save them to PNG or use some other tool (e.g. google sheets, excel)
fig = pd.DataFrame(
    {
        "model": ["initial", "add_features", "hpo"],
        "score": [-50.257112 , -50.716886, -130.850674]
    }
).plot(x="model", y="score", figsize=(8, 6)).get_figure()
fig.savefig('model_train_score.png')

# %%
# Take the 3 kaggle scores and creating a line plot to show improvement
fig = pd.DataFrame(
    {
        "test_eval": ["initial", "add_features", "hpo"],
        "score": [1.80644, 1.82964, 1.31684]
    }
).plot(x="test_eval", y="score", figsize=(8, 6)).get_figure()
fig.savefig('model_test_score.png')

# %% [markdown]
# ### Hyperparameter table

# %%
# The 3 hyperparameters we tuned with the kaggle score as the result
pd.DataFrame({
    "model": ["initial", "add_features", "hpo"],
    "hpo1": ['best_quility', 'best_quility', 'nn_options'],
    "hpo2": ['time_limit_10m', 'time_limit_10m', 'time_limit_10m'],
    "hpo3": ['none','none' , 'gbm_options'],
    "score": [1.80644, 1.82964, 1.31684]
})
# Out:
#           model          hpo1            hpo2         hpo3    score
# 0       initial  best_quility  time_limit_10m         none  1.80644
# 1  add_features  best_quility  time_limit_10m         none  1.82964
# 2           hpo    nn_options  time_limit_10m  gbm_options  1.31684
